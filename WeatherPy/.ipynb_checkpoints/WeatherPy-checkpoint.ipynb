# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "WeatherPy/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 588

# %%
citiesdf = pd.DataFrame({"City": cities, "Country": "",  "Date": "", "Latitude": "", "Longitude": "", 
                         "Max Temperature (F)": "", "Humidity (%)": "", "Cloudiness (%)": "","Wind Speed (mph)": ""})
citiesdf.head()
# Out:
#         City Country Date Latitude Longitude Max Temperature (F) Humidity (%)  \
# 0  grindavik
# 1     sokoni
# 2  busselton
# 3  taolanaro
# 4     tiznit
#
#   Cloudiness (%) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
counter = 1

print("Beginning Data Retrieval")
print("------------------------------------")

for index, row in citiesdf.iterrows():
    target_city = row["City"]
    target_url = url + "&appid=" + weather_api_key + "&units=" + units + "&q=" + target_city.replace(" ","+")   
    response = requests.get(target_url).json()

    if response["cod"] == "404":
        print("-----------------------------------")
        print("City Data is Missing")
       
    else:
        citiesdf.loc[index, 'City'] = response['name']
        citiesdf.loc[index, 'Country'] = response['sys']['country']
        citiesdf.loc[index, 'Date'] = response['dt']
        citiesdf.loc[index, 'Latitude'] = response['coord']['lat']
        citiesdf.loc[index, 'Longitude'] = response['coord']['lon']
        citiesdf.loc[index, 'Max Temperature (F)'] = response['main']['temp_max']
        citiesdf.loc[index, 'Humidity (%)'] = response['main']['humidity']
        citiesdf.loc[index, 'Cloudiness (%)'] = response['clouds']['all']
        citiesdf.loc[index, 'Wind Speed (mph)'] = response['wind']['speed']
     
        print("-----------------------------------")
        print("Processing: City # "+str(counter))
        print("The City is "+(response['name']))
        counter +=1
        
print("------------------------------------")        
print("Data Retrieval is now Complete")
time.sleep = (1.03)
# Out:
# Beginning Data Retrieval
# ------------------------------------
# -----------------------------------
# Processing: City # 1
# The City is Grindavik
# -----------------------------------
# Processing: City # 2
# The City is Sokoni
# -----------------------------------
# Processing: City # 3
# The City is Busselton
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 4
# The City is Tiznit Province
# -----------------------------------
# Processing: City # 5
# The City is Barrow
# -----------------------------------
# Processing: City # 6
# The City is Nikolskoye
# -----------------------------------
# Processing: City # 7
# The City is Rikitea
# -----------------------------------
# Processing: City # 8
# The City is Port Alfred
# -----------------------------------
# Processing: City # 9
# The City is Wānkāner
# -----------------------------------
# Processing: City # 10
# The City is East London
# -----------------------------------
# Processing: City # 11
# The City is Nchelenge
# -----------------------------------
# Processing: City # 12
# The City is Andradas
# -----------------------------------
# Processing: City # 13
# The City is Vila Franca do Campo
# -----------------------------------
# Processing: City # 14
# The City is Gurupá
# -----------------------------------
# Processing: City # 15
# The City is Torbat-e Jām
# -----------------------------------
# Processing: City # 16
# The City is Ojinaga
# -----------------------------------
# Processing: City # 17
# The City is Faanui
# -----------------------------------
# Processing: City # 18
# The City is Laas
# -----------------------------------
# Processing: City # 19
# The City is Bahía Blanca
# -----------------------------------
# Processing: City # 20
# The City is Atuona
# -----------------------------------
# Processing: City # 21
# The City is Hirado
# -----------------------------------
# Processing: City # 22
# The City is Vila Velha
# -----------------------------------
# Processing: City # 23
# The City is New Norfolk
# -----------------------------------
# Processing: City # 24
# The City is Abadan
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 25
# The City is Ushuaia
# -----------------------------------
# Processing: City # 26
# The City is Kapaa
# -----------------------------------
# Processing: City # 27
# The City is Söderhamn
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 28
# The City is Nikolayevsk-on-Amur
# -----------------------------------
# Processing: City # 29
# The City is Vaini
# -----------------------------------
# Processing: City # 30
# The City is Mawlaik
# -----------------------------------
# Processing: City # 31
# The City is Punta Arenas
# -----------------------------------
# Processing: City # 32
# The City is Sobolevo
# -----------------------------------
# Processing: City # 33
# The City is Miranda
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 34
# The City is Atyrau
# -----------------------------------
# Processing: City # 35
# The City is Puerto Ayora
# -----------------------------------
# Processing: City # 36
# The City is Nioro
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 37
# The City is Hithadhoo
# -----------------------------------
# Processing: City # 38
# The City is Carutapera
# -----------------------------------
# Processing: City # 39
# The City is Kruisfontein
# -----------------------------------
# Processing: City # 40
# The City is Pacific Grove
# -----------------------------------
# Processing: City # 41
# The City is Shilovo
# -----------------------------------
# Processing: City # 42
# The City is Najrān
# -----------------------------------
# Processing: City # 43
# The City is Vestmannaeyjar
# -----------------------------------
# Processing: City # 44
# The City is Edd
# -----------------------------------
# Processing: City # 45
# The City is Saint-Philippe
# -----------------------------------
# Processing: City # 46
# The City is Dalby
# -----------------------------------
# Processing: City # 47
# The City is Bluff
# -----------------------------------
# Processing: City # 48
# The City is Nuuk
# -----------------------------------
# Processing: City # 49
# The City is Tasiilaq
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 50
# The City is Belaya Gora
# -----------------------------------
# Processing: City # 51
# The City is Saint-Joseph
# -----------------------------------
# Processing: City # 52
# The City is Nanga Eboko
# -----------------------------------
# Processing: City # 53
# The City is Ketchikan
# -----------------------------------
# Processing: City # 54
# The City is Geraldton
# -----------------------------------
# Processing: City # 55
# The City is Castro
# -----------------------------------
# Processing: City # 56
# The City is Mataura
# -----------------------------------
# Processing: City # 57
# The City is Khatanga
# -----------------------------------
# Processing: City # 58
# The City is Olinda
# -----------------------------------
# Processing: City # 59
# The City is Cabo San Lucas
# -----------------------------------
# Processing: City # 60
# The City is Buala
# -----------------------------------
# Processing: City # 61
# The City is Butaritari
# -----------------------------------
# Processing: City # 62
# The City is Karratha
# -----------------------------------
# Processing: City # 63
# The City is Lebu
# -----------------------------------
# Processing: City # 64
# The City is Saint Paul Harbor
# -----------------------------------
# Processing: City # 65
# The City is Tabuk
# -----------------------------------
# Processing: City # 66
# The City is Margate
# -----------------------------------
# Processing: City # 67
# The City is Talcahuano
# -----------------------------------
# Processing: City # 68
# The City is Howard Springs
# -----------------------------------
# Processing: City # 69
# The City is Mayo
# -----------------------------------
# Processing: City # 70
# The City is Port Blair
# -----------------------------------
# Processing: City # 71
# The City is Hong Kong
# -----------------------------------
# Processing: City # 72
# The City is Kerava
# -----------------------------------
# Processing: City # 73
# The City is Zima
# -----------------------------------
# Processing: City # 74
# The City is Qaanaaq
# -----------------------------------
# Processing: City # 75
# The City is Tiksi
# -----------------------------------
# Processing: City # 76
# The City is Lorengau
# -----------------------------------
# Processing: City # 77
# The City is Cockburn Town
# -----------------------------------
# Processing: City # 78
# The City is Jiaojiang
# -----------------------------------
# Processing: City # 79
# The City is Morant Bay
# -----------------------------------
# Processing: City # 80
# The City is Mokhsogollokh
# -----------------------------------
# Processing: City # 81
# The City is Anadyr
# -----------------------------------
# Processing: City # 82
# The City is Srednekolymsk
# -----------------------------------
# Processing: City # 83
# The City is Cidreira
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 84
# The City is Ancud
# -----------------------------------
# Processing: City # 85
# The City is Tuktoyaktuk
# -----------------------------------
# Processing: City # 86
# The City is Tiarei
# -----------------------------------
# Processing: City # 87
# The City is Narsaq
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 88
# The City is Mount Gambier
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 89
# The City is Tahe
# -----------------------------------
# Processing: City # 90
# The City is Albany
# -----------------------------------
# Processing: City # 91
# The City is Kununurra
# -----------------------------------
# Processing: City # 92
# The City is Ambilobe
# -----------------------------------
# Processing: City # 93
# The City is Ouadda
# -----------------------------------
# Processing: City # 94
# The City is Cape Town
# -----------------------------------
# Processing: City # 95
# The City is Eha Amufu
# -----------------------------------
# Processing: City # 96
# The City is Vyshestebliyevskaya
# -----------------------------------
# Processing: City # 97
# The City is Hobart
# -----------------------------------
# Processing: City # 98
# The City is Mahon
# -----------------------------------
# Processing: City # 99
# The City is College
# -----------------------------------
# Processing: City # 100
# The City is Hirara
# -----------------------------------
# Processing: City # 101
# The City is Carnarvon
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 102
# The City is Hilo
# -----------------------------------
# Processing: City # 103
# The City is Port Elizabeth
# -----------------------------------
# Processing: City # 104
# The City is Jamestown
# -----------------------------------
# Processing: City # 105
# The City is Matara
# -----------------------------------
# Processing: City # 106
# The City is Pevek
# -----------------------------------
# Processing: City # 107
# The City is Hambantota
# -----------------------------------
# Processing: City # 108
# The City is Port-Gentil
# -----------------------------------
# Processing: City # 109
# The City is Provideniya
# -----------------------------------
# Processing: City # 110
# The City is Chui
# -----------------------------------
# Processing: City # 111
# The City is Fortuna
# -----------------------------------
# Processing: City # 112
# The City is Vanavara
# -----------------------------------
# Processing: City # 113
# The City is Waddān
# -----------------------------------
# Processing: City # 114
# The City is Cherat Cantonement
# -----------------------------------
# Processing: City # 115
# The City is Kousséri
# -----------------------------------
# Processing: City # 116
# The City is Avarua
# -----------------------------------
# Processing: City # 117
# The City is Morón
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 118
# The City is Liptovský Hrádok
# -----------------------------------
# Processing: City # 119
# The City is Portland
# -----------------------------------
# Processing: City # 120
# The City is Airai
# -----------------------------------
# Processing: City # 121
# The City is Steamboat Springs
# -----------------------------------
# Processing: City # 122
# The City is Tezu
# -----------------------------------
# Processing: City # 123
# The City is Ahipara
# -----------------------------------
# Processing: City # 124
# The City is Sinjār
# -----------------------------------
# Processing: City # 125
# The City is Suihua
# -----------------------------------
# Processing: City # 126
# The City is Mitchell
# -----------------------------------
# Processing: City # 127
# The City is Arraial do Cabo
# -----------------------------------
# Processing: City # 128
# The City is Hermanus
# -----------------------------------
# Processing: City # 129
# The City is Sur
# -----------------------------------
# Processing: City # 130
# The City is Malakal
# -----------------------------------
# Processing: City # 131
# The City is Praia da Vitória
# -----------------------------------
# Processing: City # 132
# The City is Mehamn
# -----------------------------------
# Processing: City # 133
# The City is Bredasdorp
# -----------------------------------
# Processing: City # 134
# The City is Dikson
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 135
# The City is Saint-Augustin
# -----------------------------------
# Processing: City # 136
# The City is Longyearbyen
# -----------------------------------
# Processing: City # 137
# The City is George Town
# -----------------------------------
# Processing: City # 138
# The City is Kattivākkam
# -----------------------------------
# Processing: City # 139
# The City is Kashgar
# -----------------------------------
# Processing: City # 140
# The City is Salinópolis
# -----------------------------------
# Processing: City # 141
# The City is Hasaki
# -----------------------------------
# Processing: City # 142
# The City is Río Gallegos
# -----------------------------------
# Processing: City # 143
# The City is Cayenne
# -----------------------------------
# Processing: City # 144
# The City is Mari-Turek
# -----------------------------------
# Processing: City # 145
# The City is Mar del Plata
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 146
# The City is Vao
# -----------------------------------
# Processing: City # 147
# The City is Thompson
# -----------------------------------
# Processing: City # 148
# The City is Karia
# -----------------------------------
# Processing: City # 149
# The City is Bambous Virieux
# -----------------------------------
# Processing: City # 150
# The City is Nhulunbuy
# -----------------------------------
# Processing: City # 151
# The City is Upernavik
# -----------------------------------
# Processing: City # 152
# The City is Torbay
# -----------------------------------
# Processing: City # 153
# The City is São João da Barra
# -----------------------------------
# Processing: City # 154
# The City is Marsá Maţrūḩ
# -----------------------------------
# Processing: City # 155
# The City is Wellington
# -----------------------------------
# Processing: City # 156
# The City is Plettenberg Bay
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 157
# The City is Neftegorsk
# -----------------------------------
# Processing: City # 158
# The City is Athabasca
# -----------------------------------
# Processing: City # 159
# The City is Ilulissat
# -----------------------------------
# Processing: City # 160
# The City is Kahului
# -----------------------------------
# Processing: City # 161
# The City is Maryville
# -----------------------------------
# Processing: City # 162
# The City is Port Hardy
# -----------------------------------
# Processing: City # 163
# The City is Kloulklubed
# -----------------------------------
# Processing: City # 164
# The City is Saint George
# -----------------------------------
# Processing: City # 165
# The City is Aksarka
# -----------------------------------
# Processing: City # 166
# The City is Atasū
# -----------------------------------
# Processing: City # 167
# The City is Asău
# -----------------------------------
# Processing: City # 168
# The City is Chegdomyn
# -----------------------------------
# Processing: City # 169
# The City is Yenagoa
# -----------------------------------
# Processing: City # 170
# The City is Rūdbār
# -----------------------------------
# Processing: City # 171
# The City is Necochea
# -----------------------------------
# Processing: City # 172
# The City is Codrington
# -----------------------------------
# Processing: City # 173
# The City is Rawson
# -----------------------------------
# Processing: City # 174
# The City is Pisco
# -----------------------------------
# Processing: City # 175
# The City is Mackay
# -----------------------------------
# Processing: City # 176
# The City is Treinta y Tres
# -----------------------------------
# Processing: City # 177
# The City is Flinders
# -----------------------------------
# Processing: City # 178
# The City is Cururupu
# -----------------------------------
# Processing: City # 179
# The City is Poum
# -----------------------------------
# Processing: City # 180
# The City is Bilibino
# -----------------------------------
# Processing: City # 181
# The City is Kamsack
# -----------------------------------
# Processing: City # 182
# The City is Kerrville
# -----------------------------------
# Processing: City # 183
# The City is Salalah
# -----------------------------------
# Processing: City # 184
# The City is Ust'-Ilimsk
# -----------------------------------
# Processing: City # 185
# The City is Saskylakh
# -----------------------------------
# Processing: City # 186
# The City is Egvekinot
# -----------------------------------
# Processing: City # 187
# The City is Jacareacanga
# -----------------------------------
# Processing: City # 188
# The City is Xining
# -----------------------------------
# Processing: City # 189
# The City is Álamos
# -----------------------------------
# Processing: City # 190
# The City is Maracaibo
# -----------------------------------
# Processing: City # 191
# The City is Balkanabat
# -----------------------------------
# Processing: City # 192
# The City is Alyangula
# -----------------------------------
# Processing: City # 193
# The City is Nguruka
# -----------------------------------
# Processing: City # 194
# The City is Pemangkat
# -----------------------------------
# Processing: City # 195
# The City is Svarstad
# -----------------------------------
# Processing: City # 196
# The City is La Santisima Trinidad
# -----------------------------------
# Processing: City # 197
# The City is Guerrero Negro
# -----------------------------------
# Processing: City # 198
# The City is Rouvroy
# -----------------------------------
# Processing: City # 199
# The City is Lakki
# -----------------------------------
# Processing: City # 200
# The City is Mount Isa
# -----------------------------------
# Processing: City # 201
# The City is Fairbanks
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 202
# The City is Kismayo
# -----------------------------------
# Processing: City # 203
# The City is Nanortalik
# -----------------------------------
# Processing: City # 204
# The City is Malanje
# -----------------------------------
# Processing: City # 205
# The City is Biloela
# -----------------------------------
# Processing: City # 206
# The City is San Cristobal
# -----------------------------------
# Processing: City # 207
# The City is Lavrentiya
# -----------------------------------
# Processing: City # 208
# The City is Bengkulu
# -----------------------------------
# Processing: City # 209
# The City is Itamarandiba
# -----------------------------------
# Processing: City # 210
# The City is Tari
# -----------------------------------
# Processing: City # 211
# The City is Leiva
# -----------------------------------
# Processing: City # 212
# The City is Warwick
# -----------------------------------
# Processing: City # 213
# The City is Luba
# -----------------------------------
# Processing: City # 214
# The City is Paita
# -----------------------------------
# Processing: City # 215
# The City is Luanda
# -----------------------------------
# Processing: City # 216
# The City is Coyhaique
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 217
# The City is Bathsheba
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 218
# The City is Bushehr
# -----------------------------------
# Processing: City # 219
# The City is Sibolga
# -----------------------------------
# Processing: City # 220
# The City is Ust-Nera
# -----------------------------------
# Processing: City # 221
# The City is Saldanha
# -----------------------------------
# Processing: City # 222
# The City is Leningradskiy
# -----------------------------------
# Processing: City # 223
# The City is Labuhan
# -----------------------------------
# Processing: City # 224
# The City is Russell
# -----------------------------------
# Processing: City # 225
# The City is Lumby
# -----------------------------------
# Processing: City # 226
# The City is Tigil'
# -----------------------------------
# Processing: City # 227
# The City is Hue
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 228
# The City is Yulara
# -----------------------------------
# Processing: City # 229
# The City is Tamandaré
# -----------------------------------
# Processing: City # 230
# The City is Kigoma
# -----------------------------------
# Processing: City # 231
# The City is Ayan
# -----------------------------------
# Processing: City # 232
# The City is Ribeira Grande
# -----------------------------------
# Processing: City # 233
# The City is Yeniseysk
# -----------------------------------
# Processing: City # 234
# The City is Pangnirtung
# -----------------------------------
# Processing: City # 235
# The City is Waingapu
# -----------------------------------
# Processing: City # 236
# The City is Black River
# -----------------------------------
# Processing: City # 237
# The City is Ferkessédougou
# -----------------------------------
# Processing: City # 238
# The City is Caravelas
# -----------------------------------
# Processing: City # 239
# The City is Cartagena
# -----------------------------------
# Processing: City # 240
# The City is Otorohanga
# -----------------------------------
# Processing: City # 241
# The City is Bouar
# -----------------------------------
# Processing: City # 242
# The City is Bakchar
# -----------------------------------
# Processing: City # 243
# The City is Presidencia Roque Sáenz Peña
# -----------------------------------
# Processing: City # 244
# The City is Eyl
# -----------------------------------
# Processing: City # 245
# The City is Bozhou
# -----------------------------------
# Processing: City # 246
# The City is Lagoa
# -----------------------------------
# Processing: City # 247
# The City is Amuntai
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 248
# The City is Manbij
# -----------------------------------
# Processing: City # 249
# The City is Port Macquarie
# -----------------------------------
# Processing: City # 250
# The City is Rio Grande
# -----------------------------------
# Processing: City # 251
# The City is Kaitangata
# -----------------------------------
# Processing: City # 252
# The City is Alice Springs
# -----------------------------------
# Processing: City # 253
# The City is Alofi
# -----------------------------------
# Processing: City # 254
# The City is Dhrāngadhra
# -----------------------------------
# Processing: City # 255
# The City is Mahébourg
# -----------------------------------
# Processing: City # 256
# The City is Husavik
# -----------------------------------
# Processing: City # 257
# The City is Yangi Marg`ilon
# -----------------------------------
# Processing: City # 258
# The City is Tuatapere
# -----------------------------------
# Processing: City # 259
# The City is Pierre
# -----------------------------------
# Processing: City # 260
# The City is Road Town
# -----------------------------------
# Processing: City # 261
# The City is Padang
# -----------------------------------
# Processing: City # 262
# The City is Faya
# -----------------------------------
# Processing: City # 263
# The City is Pochutla
# -----------------------------------
# Processing: City # 264
# The City is North Bend
# -----------------------------------
# Processing: City # 265
# The City is Port Lincoln
# -----------------------------------
# Processing: City # 266
# The City is Rocha
# -----------------------------------
# Processing: City # 267
# The City is Yellowknife
# -----------------------------------
# Processing: City # 268
# The City is Sambava
# -----------------------------------
# Processing: City # 269
# The City is Little Current
# -----------------------------------
# Processing: City # 270
# The City is Sept-Îles
# -----------------------------------
# Processing: City # 271
# The City is Lüderitz
# -----------------------------------
# Processing: City # 272
# The City is Xaçmaz
# -----------------------------------
# Processing: City # 273
# The City is Coquimbo
# -----------------------------------
# Processing: City # 274
# The City is Bethel
# -----------------------------------
# Processing: City # 275
# The City is Pichayevo
# -----------------------------------
# Processing: City # 276
# The City is Bandarbeyla
# -----------------------------------
# Processing: City # 277
# The City is Half Moon Bay
# -----------------------------------
# Processing: City # 278
# The City is Barra de Tecoanapa
# -----------------------------------
# Processing: City # 279
# The City is Kathu
# -----------------------------------
# Processing: City # 280
# The City is Vieux-Habitants
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 281
# The City is Kaoma
# -----------------------------------
# Processing: City # 282
# The City is Thunder Bay
# -----------------------------------
# Processing: City # 283
# The City is Nemuro
# -----------------------------------
# Processing: City # 284
# The City is Touros
# -----------------------------------
# Processing: City # 285
# The City is Talas
# -----------------------------------
# Processing: City # 286
# The City is Seydişehir
# -----------------------------------
# Processing: City # 287
# The City is Pallapatti
# -----------------------------------
# Processing: City # 288
# The City is Bonavista
# -----------------------------------
# Processing: City # 289
# The City is Tucuruí
# -----------------------------------
# Processing: City # 290
# The City is Souillac
# -----------------------------------
# Processing: City # 291
# The City is Lata
# -----------------------------------
# Processing: City # 292
# The City is Yala
# -----------------------------------
# Processing: City # 293
# The City is Klyuchi
# -----------------------------------
# Processing: City # 294
# The City is Aswān
# -----------------------------------
# Processing: City # 295
# The City is Pittsburg
# -----------------------------------
# Processing: City # 296
# The City is Shubarkuduk
# -----------------------------------
# Processing: City # 297
# The City is Bubaque
# -----------------------------------
# Processing: City # 298
# The City is Kieta
# -----------------------------------
# Processing: City # 299
# The City is Fenyi
# -----------------------------------
# Processing: City # 300
# The City is Moorhead
# -----------------------------------
# Processing: City # 301
# The City is Naze
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 302
# The City is Campina Verde
# -----------------------------------
# Processing: City # 303
# The City is Yar-Sale
# -----------------------------------
# Processing: City # 304
# The City is San Joaquin
# -----------------------------------
# Processing: City # 305
# The City is Kamenka
# -----------------------------------
# Processing: City # 306
# The City is Ammon
# -----------------------------------
# Processing: City # 307
# The City is Nara
# -----------------------------------
# Processing: City # 308
# The City is Beatrice
# -----------------------------------
# Processing: City # 309
# The City is Selaphum
# -----------------------------------
# Processing: City # 310
# The City is Mahon
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 311
# The City is Kapoeta
# -----------------------------------
# Processing: City # 312
# The City is Obo
# -----------------------------------
# Processing: City # 313
# The City is San Rafael
# -----------------------------------
# Processing: City # 314
# The City is Naryan-Mar
# -----------------------------------
# Processing: City # 315
# The City is Bay Roberts
# -----------------------------------
# Processing: City # 316
# The City is Meadow Lake
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 317
# The City is Stephenville
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 318
# The City is Kathmandu
# -----------------------------------
# Processing: City # 319
# The City is Kenai
# -----------------------------------
# Processing: City # 320
# The City is Tonantins
# -----------------------------------
# Processing: City # 321
# The City is Kumul
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 322
# The City is Jalu
# -----------------------------------
# Processing: City # 323
# The City is Hutang
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 324
# The City is Dalupirip
# -----------------------------------
# Processing: City # 325
# The City is Hualmay
# -----------------------------------
# Processing: City # 326
# The City is Clyde River
# -----------------------------------
# Processing: City # 327
# The City is Port Augusta
# -----------------------------------
# Processing: City # 328
# The City is Sorong
# -----------------------------------
# Processing: City # 329
# The City is Serpa
# -----------------------------------
# Processing: City # 330
# The City is Kendari
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 331
# The City is Le Vauclin
# -----------------------------------
# Processing: City # 332
# The City is La Ronge
# -----------------------------------
# Processing: City # 333
# The City is Vilhena
# -----------------------------------
# Processing: City # 334
# The City is Opunake
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 335
# The City is Santa Inês
# -----------------------------------
# Processing: City # 336
# The City is Arlit
# -----------------------------------
# Processing: City # 337
# The City is Pailón
# -----------------------------------
# Processing: City # 338
# The City is Grand Bank
# -----------------------------------
# Processing: City # 339
# The City is Ostrovnoy
# -----------------------------------
# Processing: City # 340
# The City is Iqaluit
# -----------------------------------
# Processing: City # 341
# The City is Shache
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 342
# The City is Bagno a Ripoli
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 343
# The City is Panguna
# -----------------------------------
# Processing: City # 344
# The City is Banjar
# -----------------------------------
# Processing: City # 345
# The City is Smoky Lake
# -----------------------------------
# Processing: City # 346
# The City is Sussex
# -----------------------------------
# Processing: City # 347
# The City is Yeppoon
# -----------------------------------
# Processing: City # 348
# The City is Umluj
# -----------------------------------
# Processing: City # 349
# The City is Laguna
# -----------------------------------
# Processing: City # 350
# The City is Kaeo
# -----------------------------------
# Processing: City # 351
# The City is Pilar
# -----------------------------------
# Processing: City # 352
# The City is Keminmaa
# -----------------------------------
# Processing: City # 353
# The City is Aripuanã
# -----------------------------------
# Processing: City # 354
# The City is Lashio
# -----------------------------------
# Processing: City # 355
# The City is Cody
# -----------------------------------
# Processing: City # 356
# The City is Mogok
# -----------------------------------
# Processing: City # 357
# The City is Henties Bay
# -----------------------------------
# Processing: City # 358
# The City is San Patricio
# -----------------------------------
# Processing: City # 359
# The City is Perivoli
# -----------------------------------
# Processing: City # 360
# The City is Rome
# -----------------------------------
# Processing: City # 361
# The City is Żyrardów
# -----------------------------------
# Processing: City # 362
# The City is Havelock
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 363
# The City is Same
# -----------------------------------
# Processing: City # 364
# The City is Porto Velho
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 365
# The City is Tabou
# -----------------------------------
# Processing: City # 366
# The City is Chapais
# -----------------------------------
# Processing: City # 367
# The City is Aykhal
# -----------------------------------
# Processing: City # 368
# The City is Tulum
# -----------------------------------
# Processing: City # 369
# The City is Yuli
# -----------------------------------
# Processing: City # 370
# The City is Coswig
# -----------------------------------
# Processing: City # 371
# The City is Dunedin
# -----------------------------------
# Processing: City # 372
# The City is Vostok
# -----------------------------------
# Processing: City # 373
# The City is Paamiut
# -----------------------------------
# Processing: City # 374
# The City is Itaporanga
# -----------------------------------
# Processing: City # 375
# The City is Goderich
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 376
# The City is Oranjemund
# -----------------------------------
# Processing: City # 377
# The City is Mareeba
# -----------------------------------
# Processing: City # 378
# The City is Merauke
# -----------------------------------
# Processing: City # 379
# The City is Chokurdakh
# -----------------------------------
# Processing: City # 380
# The City is Celestún
# -----------------------------------
# Processing: City # 381
# The City is Abbeville
# -----------------------------------
# Processing: City # 382
# The City is Samarai
# -----------------------------------
# Processing: City # 383
# The City is Rosário Oeste
# -----------------------------------
# Processing: City # 384
# The City is Fort Abbas
# -----------------------------------
# Processing: City # 385
# The City is Kupang
# -----------------------------------
# Processing: City # 386
# The City is Zyryanovsk
# -----------------------------------
# Processing: City # 387
# The City is Manaure
# -----------------------------------
# Processing: City # 388
# The City is Uporovo
# -----------------------------------
# Processing: City # 389
# The City is Maniitsoq
# -----------------------------------
# Processing: City # 390
# The City is Katsuura
# -----------------------------------
# Processing: City # 391
# The City is Slave Lake
# -----------------------------------
# Processing: City # 392
# The City is Eureka
# -----------------------------------
# Processing: City # 393
# The City is Puerto Cabezas
# -----------------------------------
# Processing: City # 394
# The City is Māngrol
# -----------------------------------
# Processing: City # 395
# The City is Bogandé
# -----------------------------------
# Processing: City # 396
# The City is Porto Empedocle
# -----------------------------------
# Processing: City # 397
# The City is Santa Isabel Rio Negro
# -----------------------------------
# Processing: City # 398
# The City is Acarí
# -----------------------------------
# Processing: City # 399
# The City is San Quintín
# -----------------------------------
# Processing: City # 400
# The City is Isangel
# -----------------------------------
# Processing: City # 401
# The City is Rørvik
# -----------------------------------
# Processing: City # 402
# The City is At-Bashi
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 403
# The City is Esperance
# -----------------------------------
# Processing: City # 404
# The City is Domoni
# -----------------------------------
# Processing: City # 405
# The City is Hérouville-Saint-Clair
# -----------------------------------
# Processing: City # 406
# The City is Ponta do Sol
# -----------------------------------
# Processing: City # 407
# The City is Saint Lawrence
# -----------------------------------
# Processing: City # 408
# The City is Concepción
# -----------------------------------
# Processing: City # 409
# The City is Kasangulu
# -----------------------------------
# Processing: City # 410
# The City is Cherskiy
# -----------------------------------
# Processing: City # 411
# The City is Arman'
# -----------------------------------
# Processing: City # 412
# The City is Miraflores
# -----------------------------------
# Processing: City # 413
# The City is Kédougou
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 414
# The City is Korla
# -----------------------------------
# Processing: City # 415
# The City is Norman Wells
# -----------------------------------
# Processing: City # 416
# The City is Miajadas
# -----------------------------------
# Processing: City # 417
# The City is Banda Aceh
# -----------------------------------
# Processing: City # 418
# The City is Pichucalco
# -----------------------------------
# Processing: City # 419
# The City is Moengo
# -----------------------------------
# Processing: City # 420
# The City is Taozhuang
# -----------------------------------
# Processing: City # 421
# The City is Muros
# -----------------------------------
# Processing: City # 422
# The City is Adrar
# -----------------------------------
# Processing: City # 423
# The City is San Miguel de Tucumán
# -----------------------------------
# Processing: City # 424
# The City is Porto Santo
# -----------------------------------
# Processing: City # 425
# The City is Rundu
# -----------------------------------
# Processing: City # 426
# The City is Cotonou
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 427
# The City is Abu Kamal
# -----------------------------------
# Processing: City # 428
# The City is Arrondissement de Laon
# -----------------------------------
# Processing: City # 429
# The City is Talnakh
# -----------------------------------
# Processing: City # 430
# The City is Lucapa
# -----------------------------------
# Processing: City # 431
# The City is Vágur
# -----------------------------------
# Processing: City # 432
# The City is Chimoré
# -----------------------------------
# Processing: City # 433
# The City is Godhra
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 434
# The City is Hay River
# -----------------------------------
# Processing: City # 435
# The City is Jerome
# -----------------------------------
# Processing: City # 436
# The City is Pagudpud
# -----------------------------------
# Processing: City # 437
# The City is Derzhavīnsk
# -----------------------------------
# Processing: City # 438
# The City is St. George's
# -----------------------------------
# Processing: City # 439
# The City is Fillan
# -----------------------------------
# Processing: City # 440
# The City is Coihueco
# -----------------------------------
# Processing: City # 441
# The City is Sudak
# -----------------------------------
# Processing: City # 442
# The City is Buluang
# -----------------------------------
# Processing: City # 443
# The City is Lubango
# -----------------------------------
# Processing: City # 444
# The City is Chaoyang
# -----------------------------------
# Processing: City # 445
# The City is Temir
# -----------------------------------
# Processing: City # 446
# The City is Mumford
# -----------------------------------
# Processing: City # 447
# The City is Aklavik
# -----------------------------------
# Processing: City # 448
# The City is Alekseyevsk
# -----------------------------------
# Processing: City # 449
# The City is Kouroussa
# -----------------------------------
# Processing: City # 450
# The City is San Andrés
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 451
# The City is Maţāy
# -----------------------------------
# Processing: City # 452
# The City is Kavieng
# -----------------------------------
# Processing: City # 453
# The City is Atambua
# -----------------------------------
# Processing: City # 454
# The City is Sydney Mines
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 455
# The City is Athens
# -----------------------------------
# Processing: City # 456
# The City is Meulaboh
# -----------------------------------
# Processing: City # 457
# The City is Buraidah
# -----------------------------------
# Processing: City # 458
# The City is Port Antonio
# -----------------------------------
# Processing: City # 459
# The City is Bernal
# -----------------------------------
# Processing: City # 460
# The City is Bundaberg
# -----------------------------------
# Processing: City # 461
# The City is Klaksvík
# -----------------------------------
# Processing: City # 462
# The City is Kirakira
# -----------------------------------
# Processing: City # 463
# The City is Murray Bridge
# -----------------------------------
# Processing: City # 464
# The City is Buerarema
# -----------------------------------
# Processing: City # 465
# The City is Kudahuvadhoo
# -----------------------------------
# Processing: City # 466
# The City is Marck
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 467
# The City is Kulhudhuffushi
# -----------------------------------
# Processing: City # 468
# The City is Along
# -----------------------------------
# Processing: City # 469
# The City is Baní
# -----------------------------------
# Processing: City # 470
# The City is Jumla
# -----------------------------------
# Processing: City # 471
# The City is Develi
# -----------------------------------
# Processing: City # 472
# The City is Sekichō-furumaya
# -----------------------------------
# Processing: City # 473
# The City is Nouadhibou
# -----------------------------------
# Processing: City # 474
# The City is Francistown
# -----------------------------------
# Processing: City # 475
# The City is Parintins
# -----------------------------------
# Processing: City # 476
# The City is Baharly
# -----------------------------------
# Processing: City # 477
# The City is Pancol
# -----------------------------------
# Processing: City # 478
# The City is Haines Junction
# -----------------------------------
# Processing: City # 479
# The City is Honiara
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 480
# The City is Severo-Kuril'sk
# -----------------------------------
# Processing: City # 481
# The City is Hanmer Springs
# -----------------------------------
# Processing: City # 482
# The City is Lanivtsi
# -----------------------------------
# Processing: City # 483
# The City is Aniva
# -----------------------------------
# Processing: City # 484
# The City is Miran Shah
# -----------------------------------
# Processing: City # 485
# The City is Cap-aux-Meules
# -----------------------------------
# Processing: City # 486
# The City is Envira
# -----------------------------------
# Processing: City # 487
# The City is Bahía Honda
# -----------------------------------
# Processing: City # 488
# The City is Guangyuan
# -----------------------------------
# Processing: City # 489
# The City is Pionerskiy
# -----------------------------------
# Processing: City # 490
# The City is Codajás
# -----------------------------------
# Processing: City # 491
# The City is Arusha
# -----------------------------------
# Processing: City # 492
# The City is Pogranichnyy
# -----------------------------------
# Processing: City # 493
# The City is Valleyview
# -----------------------------------
# Processing: City # 494
# The City is Bambanglipuro
# -----------------------------------
# Processing: City # 495
# The City is Sisimiut
# -----------------------------------
# Processing: City # 496
# The City is Sulangan
# -----------------------------------
# Processing: City # 497
# The City is Skibbereen
# -----------------------------------
# Processing: City # 498
# The City is Winnemucca
# -----------------------------------
# Processing: City # 499
# The City is Qinzhou
# -----------------------------------
# Processing: City # 500
# The City is Beipiao
# -----------------------------------
# Processing: City # 501
# The City is Zuwārah
# -----------------------------------
# Processing: City # 502
# The City is Zhangye
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 503
# The City is Monrovia
# -----------------------------------
# Processing: City # 504
# The City is Strelka
# -----------------------------------
# Processing: City # 505
# The City is Baryshivka
# -----------------------------------
# Processing: City # 506
# The City is Dingle
# -----------------------------------
# Processing: City # 507
# The City is Virginia Beach
# -----------------------------------
# Processing: City # 508
# The City is Burirao
# -----------------------------------
# Processing: City # 509
# The City is ‘Ewa Beach
# -----------------------------------
# Processing: City # 510
# The City is Nome
# -----------------------------------
# Processing: City # 511
# The City is High Level
# -----------------------------------
# Processing: City # 512
# The City is Vitim
# -----------------------------------
# Processing: City # 513
# The City is Parry Sound
# -----------------------------------
# Processing: City # 514
# The City is Kavaratti
# -----------------------------------
# Processing: City # 515
# The City is Inírida
# -----------------------------------
# Processing: City # 516
# The City is Khandyga
# -----------------------------------
# Processing: City # 517
# The City is Beringovskiy
# -----------------------------------
# Processing: City # 518
# The City is Tazovsky
# -----------------------------------
# Processing: City # 519
# The City is Tambopata
# -----------------------------------
# Processing: City # 520
# The City is Toora-Khem
# -----------------------------------
# Processing: City # 521
# The City is Nishihara
# -----------------------------------
# Processing: City # 522
# The City is Naujamiestis
# -----------------------------------
# Processing: City # 523
# The City is Tamayo
# -----------------------------------
# Processing: City # 524
# The City is Te Anau
# -----------------------------------
# Processing: City # 525
# The City is Ladário
# -----------------------------------
# Processing: City # 526
# The City is Porosozero
# -----------------------------------
# Processing: City # 527
# The City is Kasempa
# -----------------------------------
# Processing: City # 528
# The City is Cooma
# -----------------------------------
# Processing: City # 529
# The City is Qinhuangdao
# -----------------------------------
# Processing: City # 530
# The City is Nushki
# -----------------------------------
# Processing: City # 531
# The City is São Filipe
# -----------------------------------
# Processing: City # 532
# The City is Discovery Bay
# -----------------------------------
# Processing: City # 533
# The City is Chaihe
# -----------------------------------
# City Data is Missing
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 534
# The City is San Policarpo
# -----------------------------------
# Processing: City # 535
# The City is Iwanai
# -----------------------------------
# Processing: City # 536
# The City is Crotone
# -----------------------------------
# Processing: City # 537
# The City is Province of Brindisi
# -----------------------------------
# Processing: City # 538
# The City is Mpanda
# -----------------------------------
# Processing: City # 539
# The City is Magdagachi
# -----------------------------------
# Processing: City # 540
# The City is Ucluelet
# -----------------------------------
# Processing: City # 541
# The City is Pinawa
# -----------------------------------
# Processing: City # 542
# The City is Novorzhev
# -----------------------------------
# Processing: City # 543
# The City is Umm Kaddadah
# -----------------------------------
# Processing: City # 544
# The City is Pangody
# ------------------------------------
# Data Retrieval is now Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citiesdf.count()
# Out:
# City                   588
# Country                588
# Date                   588
# Latitude               588
# Longitude              588
# Max Temperature (F)    588
# Humidity (%)           588
# Cloudiness (%)         588
# Wind Speed (mph)       588
# dtype: int64

# %%
citiesdf.to_csv("WeatherPy_City.csv", index=False)
citiesdf = pd.read_csv("WeatherPy_City.csv")

# %%
#Drop blank cells
citiesdf.dropna(inplace=True)
citiesdf.head()
# Out:
#               City Country          Date  Latitude  Longitude  \
# 0        Grindavik      IS  1.595129e+09     63.84     -22.43
# 1           Sokoni      TZ  1.595129e+09     -6.43      39.55
# 2        Busselton      AU  1.595129e+09    -33.65     115.33
# 4  Tiznit Province      MA  1.595129e+09     29.58      -9.50
# 5           Barrow      US  1.595129e+09     71.29    -156.79
#
#    Max Temperature (F)  Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0                46.40          87.0            20.0             11.41
# 1                77.40          70.0             0.0             20.76
# 2                57.00          83.0           100.0              1.99
# 4                76.87          32.0             0.0              1.66
# 5                37.40          74.0            90.0             13.87

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build the scatter plots 
plt.scatter(citiesdf['Latitude'], citiesdf['Max Temperature (F)'], linewidth=1, marker="o", 
            alpha=0.5, facecolor="blue", edgecolor="black", label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature {time.strftime('%m/%d/%y')}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperture (F)")
plt.grid(True)

plt.savefig("Latitude_Temperature.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
citiesdf=citiesdf[(citiesdf['Humidity (%)']<=100)]

# %%
# Build the scatter plots 
plt.scatter(citiesdf['Latitude'], citiesdf['Humidity (%)'], linewidth=1, marker="o", 
            alpha=0.5, facecolor="blue", edgecolor="black", label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity {time.strftime('%m/%d/%y')}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.savefig("Latitude_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots 
plt.scatter(citiesdf['Latitude'], citiesdf['Cloudiness (%)'], linewidth=1, marker="o", 
            alpha=0.5, facecolor="blue", edgecolor="black", label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness {time.strftime('%m/%d/%y')}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

plt.savefig("Latitude_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots 
plt.scatter(citiesdf['Latitude'], citiesdf['Wind Speed (mph)'], linewidth=1, marker="o", 
            alpha=0.5, facecolor="blue", edgecolor="black", label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed {time.strftime('%m/%d/%y')}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

plt.savefig("Latitude_WindSpeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
