# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "WeatherPy/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %%
citiesdf = pd.DataFrame({"City": cities, "Country": "",  "Date": "", "Latitude": "", "Longitude": "", 
                         "Max Temperature (F)": "", "Humidity (%)": "", "Cloudiness (%)": "","Wind Speed (mph)": ""})
citiesdf.head()
# Out:
#              City Country Date Latitude Longitude Max Temperature (F)  \
# 0         rikitea
# 1  port macquarie
# 2           vardo
# 3           bluff
# 4       tazovskiy
#
#   Humidity (%) Cloudiness (%) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
counter = 1

print("Beginning Data Retrieval")
print("------------------------------------")

for index, row in citiesdf.iterrows():
    target_city = row["City"]
    target_url = url + "&appid=" + weather_api_key + "&units=" + units + "&q=" + target_city.replace(" ","+")   
    response = requests.get(target_url).json()

    if response["cod"] == "404":
        print("-----------------------------------")
        print("City Data is Missing")
       
    else:
        citiesdf.loc[index, 'City'] = response['name']
        citiesdf.loc[index, 'Country'] = response['sys']['country']
        citiesdf.loc[index, 'Date'] = response['dt']
        citiesdf.loc[index, 'Latitude'] = response['coord']['lat']
        citiesdf.loc[index, 'Longitude'] = response['coord']['lon']
        citiesdf.loc[index, 'Max Temperature (F)'] = response['main']['temp_max']
        citiesdf.loc[index, 'Humidity (%)'] = response['main']['humidity']
        citiesdf.loc[index, 'Cloudiness (%)'] = response['clouds']['all']
        citiesdf.loc[index, 'Wind Speed (mph)'] = response['wind']['speed']
     
        print("-----------------------------------")
        print("Processing: City # "+str(counter))
        print("The City is "+(response['name']))
        counter +=1
        
print("------------------------------------")        
print("Data Retrieval is now Complete")
time.sleep = (1.03)
# Out:
# Beginning Data Retrieval
# ------------------------------------
# -----------------------------------
# Processing: City # 1
# The City is Rikitea
# -----------------------------------
# Processing: City # 2
# The City is Port Macquarie
# -----------------------------------
# Processing: City # 3
# The City is Vardø
# -----------------------------------
# Processing: City # 4
# The City is Bluff
# -----------------------------------
# Processing: City # 5
# The City is Tazovsky
# -----------------------------------
# Processing: City # 6
# The City is Cidreira
# -----------------------------------
# Processing: City # 7
# The City is Anadyr
# -----------------------------------
# Processing: City # 8
# The City is Katsuura
# -----------------------------------
# Processing: City # 9
# The City is Punta Arenas
# -----------------------------------
# Processing: City # 10
# The City is Rawson
# -----------------------------------
# Processing: City # 11
# The City is Avarua
# -----------------------------------
# Processing: City # 12
# The City is Rivadavia
# -----------------------------------
# Processing: City # 13
# The City is Caravelas
# -----------------------------------
# Processing: City # 14
# The City is Ushuaia
# -----------------------------------
# Processing: City # 15
# The City is Lüderitz
# -----------------------------------
# Processing: City # 16
# The City is Krasnosel'kup
# -----------------------------------
# Processing: City # 17
# The City is Hilo
# -----------------------------------
# Processing: City # 18
# The City is Mataura
# -----------------------------------
# Processing: City # 19
# The City is Vaini
# -----------------------------------
# Processing: City # 20
# The City is Biltine
# -----------------------------------
# Processing: City # 21
# The City is Kahului
# -----------------------------------
# Processing: City # 22
# The City is Busselton
# -----------------------------------
# Processing: City # 23
# The City is Albany
# -----------------------------------
# Processing: City # 24
# The City is Ekibastuz
# -----------------------------------
# Processing: City # 25
# The City is Arraial do Cabo
# -----------------------------------
# Processing: City # 26
# The City is Saint-Philippe
# -----------------------------------
# Processing: City # 27
# The City is Hong Kong
# -----------------------------------
# Processing: City # 28
# The City is Pacific Grove
# -----------------------------------
# Processing: City # 29
# The City is Carnarvon
# -----------------------------------
# Processing: City # 30
# The City is Hobart
# -----------------------------------
# Processing: City # 31
# The City is Talnakh
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 32
# The City is Labuhan
# -----------------------------------
# Processing: City # 33
# The City is Tuktoyaktuk
# -----------------------------------
# Processing: City # 34
# The City is Lorengau
# -----------------------------------
# Processing: City # 35
# The City is Port Alfred
# -----------------------------------
# Processing: City # 36
# The City is Paita
# -----------------------------------
# Processing: City # 37
# The City is Khatanga
# -----------------------------------
# Processing: City # 38
# The City is Hambantota
# -----------------------------------
# Processing: City # 39
# The City is Kirsanov
# -----------------------------------
# Processing: City # 40
# The City is Aklavik
# -----------------------------------
# Processing: City # 41
# The City is Saint Paul Harbor
# -----------------------------------
# Processing: City # 42
# The City is Lixouri
# -----------------------------------
# Processing: City # 43
# The City is Vestmannaeyjar
# -----------------------------------
# Processing: City # 44
# The City is Kaitangata
# -----------------------------------
# Processing: City # 45
# The City is San Rafael
# -----------------------------------
# Processing: City # 46
# The City is Jamestown
# -----------------------------------
# Processing: City # 47
# The City is Hithadhoo
# -----------------------------------
# Processing: City # 48
# The City is Oktyabr'skoye
# -----------------------------------
# Processing: City # 49
# The City is Katobu
# -----------------------------------
# Processing: City # 50
# The City is Mampong
# -----------------------------------
# Processing: City # 51
# The City is Mar del Plata
# -----------------------------------
# Processing: City # 52
# The City is Mehamn
# -----------------------------------
# Processing: City # 53
# The City is Arona
# -----------------------------------
# Processing: City # 54
# The City is La Santisima Trinidad
# -----------------------------------
# Processing: City # 55
# The City is Mlonggo
# -----------------------------------
# Processing: City # 56
# The City is Broome
# -----------------------------------
# Processing: City # 57
# The City is Yellowknife
# -----------------------------------
# Processing: City # 58
# The City is Mabaruma
# -----------------------------------
# Processing: City # 59
# The City is Kapaa
# -----------------------------------
# Processing: City # 60
# The City is Makungu
# -----------------------------------
# Processing: City # 61
# The City is Castro
# -----------------------------------
# Processing: City # 62
# The City is Zyryanka
# -----------------------------------
# Processing: City # 63
# The City is Sumenep
# -----------------------------------
# Processing: City # 64
# The City is Port Elizabeth
# -----------------------------------
# Processing: City # 65
# The City is Roald
# -----------------------------------
# Processing: City # 66
# The City is Wawa
# -----------------------------------
# Processing: City # 67
# The City is Atuona
# -----------------------------------
# Processing: City # 68
# The City is Barrow
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 69
# The City is Zelenoborsk
# -----------------------------------
# Processing: City # 70
# The City is Santiago de Cuba
# -----------------------------------
# Processing: City # 71
# The City is Geraldton
# -----------------------------------
# Processing: City # 72
# The City is Lebu
# -----------------------------------
# Processing: City # 73
# The City is Sevsk
# -----------------------------------
# Processing: City # 74
# The City is Torbay
# -----------------------------------
# Processing: City # 75
# The City is Kruisfontein
# -----------------------------------
# Processing: City # 76
# The City is Dikson
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 77
# The City is Baft
# -----------------------------------
# Processing: City # 78
# The City is Leningradskiy
# -----------------------------------
# Processing: City # 79
# The City is Hashtrūd
# -----------------------------------
# Processing: City # 80
# The City is Liverpool
# -----------------------------------
# Processing: City # 81
# The City is Lavrentiya
# -----------------------------------
# Processing: City # 82
# The City is Atambua
# -----------------------------------
# Processing: City # 83
# The City is Strezhevoy
# -----------------------------------
# Processing: City # 84
# The City is Aripuanã
# -----------------------------------
# Processing: City # 85
# The City is Bambanglipuro
# -----------------------------------
# Processing: City # 86
# The City is Young
# -----------------------------------
# Processing: City # 87
# The City is Nioki
# -----------------------------------
# Processing: City # 88
# The City is Ugoofaaru
# -----------------------------------
# Processing: City # 89
# The City is North Bend
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 90
# The City is Chunhuhub
# -----------------------------------
# Processing: City # 91
# The City is Puerto Ayora
# -----------------------------------
# Processing: City # 92
# The City is Cape Town
# -----------------------------------
# Processing: City # 93
# The City is Ponta do Sol
# -----------------------------------
# Processing: City # 94
# The City is Camacupa
# -----------------------------------
# Processing: City # 95
# The City is Severnyy
# -----------------------------------
# Processing: City # 96
# The City is East London
# -----------------------------------
# Processing: City # 97
# The City is Upernavik
# -----------------------------------
# Processing: City # 98
# The City is Pirenópolis
# -----------------------------------
# Processing: City # 99
# The City is Entre Rios
# -----------------------------------
# Processing: City # 100
# The City is Muros
# -----------------------------------
# Processing: City # 101
# The City is Aloleng
# -----------------------------------
# Processing: City # 102
# The City is Pangody
# -----------------------------------
# Processing: City # 103
# The City is Esperance
# -----------------------------------
# Processing: City # 104
# The City is Ngunguru
# -----------------------------------
# Processing: City # 105
# The City is Meru
# -----------------------------------
# Processing: City # 106
# The City is Tuatapere
# -----------------------------------
# Processing: City # 107
# The City is Severo-Kuril'sk
# -----------------------------------
# Processing: City # 108
# The City is Madingou
# -----------------------------------
# Processing: City # 109
# The City is Iqaluit
# -----------------------------------
# Processing: City # 110
# The City is Mount Isa
# -----------------------------------
# Processing: City # 111
# The City is Daru
# -----------------------------------
# Processing: City # 112
# The City is Bethel
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 113
# The City is Ribeira Grande
# -----------------------------------
# Processing: City # 114
# The City is Thompson
# -----------------------------------
# Processing: City # 115
# The City is Chauk
# -----------------------------------
# Processing: City # 116
# The City is Pevek
# -----------------------------------
# Processing: City # 117
# The City is Umri
# -----------------------------------
# Processing: City # 118
# The City is Sorong
# -----------------------------------
# Processing: City # 119
# The City is Tibati
# -----------------------------------
# Processing: City # 120
# The City is Shache
# -----------------------------------
# Processing: City # 121
# The City is Bolgatanga
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 122
# The City is Terrace Bay
# -----------------------------------
# Processing: City # 123
# The City is Yatou
# -----------------------------------
# Processing: City # 124
# The City is Hermanus
# -----------------------------------
# Processing: City # 125
# The City is Palmer
# -----------------------------------
# Processing: City # 126
# The City is Lompoc
# -----------------------------------
# Processing: City # 127
# The City is Valparaíso
# -----------------------------------
# Processing: City # 128
# The City is George Town
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 129
# The City is Axum
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 130
# The City is Natal
# -----------------------------------
# Processing: City # 131
# The City is Innisfail
# -----------------------------------
# Processing: City # 132
# The City is Kodinsk
# -----------------------------------
# Processing: City # 133
# The City is Flinders
# -----------------------------------
# Processing: City # 134
# The City is Vilyuysk
# -----------------------------------
# Processing: City # 135
# The City is Santo Antônio do Leverger
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 136
# The City is Morón
# -----------------------------------
# Processing: City # 137
# The City is Kushiro
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 138
# The City is Dongsheng
# -----------------------------------
# Processing: City # 139
# The City is Shafranovo
# -----------------------------------
# Processing: City # 140
# The City is Faanui
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 141
# The City is Brae
# -----------------------------------
# Processing: City # 142
# The City is Te Anau
# -----------------------------------
# Processing: City # 143
# The City is Souillac
# -----------------------------------
# Processing: City # 144
# The City is Bodaybo
# -----------------------------------
# Processing: City # 145
# The City is Airai
# -----------------------------------
# Processing: City # 146
# The City is Sur
# -----------------------------------
# Processing: City # 147
# The City is Paramonga
# -----------------------------------
# Processing: City # 148
# The City is Jaciara
# -----------------------------------
# Processing: City # 149
# The City is Samarai
# -----------------------------------
# Processing: City # 150
# The City is Garoowe
# -----------------------------------
# Processing: City # 151
# The City is Yüksekova
# -----------------------------------
# Processing: City # 152
# The City is Morondava
# -----------------------------------
# Processing: City # 153
# The City is Leh
# -----------------------------------
# Processing: City # 154
# The City is Searcy
# -----------------------------------
# Processing: City # 155
# The City is Sibu
# -----------------------------------
# Processing: City # 156
# The City is Teahupoo
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 157
# The City is Saldanha
# -----------------------------------
# Processing: City # 158
# The City is Portland
# -----------------------------------
# Processing: City # 159
# The City is Constantine
# -----------------------------------
# Processing: City # 160
# The City is Loknya
# -----------------------------------
# Processing: City # 161
# The City is Mahébourg
# -----------------------------------
# Processing: City # 162
# The City is Pisco
# -----------------------------------
# Processing: City # 163
# The City is Tigtabon
# -----------------------------------
# Processing: City # 164
# The City is Hagdan
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 165
# The City is Itarema
# -----------------------------------
# Processing: City # 166
# The City is Narsaq
# -----------------------------------
# Processing: City # 167
# The City is Pingliang
# -----------------------------------
# Processing: City # 168
# The City is Kuching
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 169
# The City is Vao
# -----------------------------------
# Processing: City # 170
# The City is Kavieng
# -----------------------------------
# Processing: City # 171
# The City is Constitución
# -----------------------------------
# Processing: City # 172
# The City is Bengkulu
# -----------------------------------
# Processing: City # 173
# The City is New Norfolk
# -----------------------------------
# Processing: City # 174
# The City is Vila Franca do Campo
# -----------------------------------
# Processing: City # 175
# The City is Minot
# -----------------------------------
# Processing: City # 176
# The City is Klaksvík
# -----------------------------------
# Processing: City # 177
# The City is Chui
# -----------------------------------
# Processing: City # 178
# The City is Cabo San Lucas
# -----------------------------------
# Processing: City # 179
# The City is Zihuatanejo
# -----------------------------------
# Processing: City # 180
# The City is Butaritari
# -----------------------------------
# Processing: City # 181
# The City is Nikolskoye
# -----------------------------------
# Processing: City # 182
# The City is Hamilton
# -----------------------------------
# Processing: City # 183
# The City is Aipe
# -----------------------------------
# Processing: City # 184
# The City is Baraki Barak
# -----------------------------------
# Processing: City # 185
# The City is Garden City
# -----------------------------------
# Processing: City # 186
# The City is Palana
# -----------------------------------
# Processing: City # 187
# The City is Isangel
# -----------------------------------
# Processing: City # 188
# The City is Baruun-Urt
# -----------------------------------
# Processing: City # 189
# The City is Bathsheba
# -----------------------------------
# Processing: City # 190
# The City is Panjāb
# -----------------------------------
# Processing: City # 191
# The City is Mīnāb
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 192
# The City is Zhigansk
# -----------------------------------
# Processing: City # 193
# The City is Edinburgh
# -----------------------------------
# Processing: City # 194
# The City is Harper
# -----------------------------------
# Processing: City # 195
# The City is Pangnirtung
# -----------------------------------
# Processing: City # 196
# The City is Buchanan
# -----------------------------------
# Processing: City # 197
# The City is Bambous Virieux
# -----------------------------------
# Processing: City # 198
# The City is Ancud
# -----------------------------------
# Processing: City # 199
# The City is Bourail
# -----------------------------------
# Processing: City # 200
# The City is The Pas
# -----------------------------------
# Processing: City # 201
# The City is Namatanai
# -----------------------------------
# Processing: City # 202
# The City is Nantucket
# -----------------------------------
# Processing: City # 203
# The City is Houma
# -----------------------------------
# Processing: City # 204
# The City is Gladstone
# -----------------------------------
# Processing: City # 205
# The City is Cedar City
# -----------------------------------
# Processing: City # 206
# The City is Longyearbyen
# -----------------------------------
# Processing: City # 207
# The City is Vanimo
# -----------------------------------
# Processing: City # 208
# The City is Clarence Town
# -----------------------------------
# Processing: City # 209
# The City is Lanzhou
# -----------------------------------
# Processing: City # 210
# The City is Mossamedes
# -----------------------------------
# Processing: City # 211
# The City is Salem
# -----------------------------------
# Processing: City # 212
# The City is Sitka
# -----------------------------------
# Processing: City # 213
# The City is Brownsville
# -----------------------------------
# Processing: City # 214
# The City is Bolobo
# -----------------------------------
# Processing: City # 215
# The City is Nālūt
# -----------------------------------
# Processing: City # 216
# The City is Nyurba
# -----------------------------------
# Processing: City # 217
# The City is Qaanaaq
# -----------------------------------
# Processing: City # 218
# The City is Fortuna
# -----------------------------------
# Processing: City # 219
# The City is Ereymentau
# -----------------------------------
# Processing: City # 220
# The City is Olafsvik
# -----------------------------------
# Processing: City # 221
# The City is Shiyan
# -----------------------------------
# Processing: City # 222
# The City is Oliveira do Hospital
# -----------------------------------
# Processing: City # 223
# The City is San Policarpo
# -----------------------------------
# Processing: City # 224
# The City is Macalelon
# -----------------------------------
# Processing: City # 225
# The City is Mount Gambier
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 226
# The City is Immokalee
# -----------------------------------
# Processing: City # 227
# The City is Hasaki
# -----------------------------------
# Processing: City # 228
# The City is Avera
# -----------------------------------
# Processing: City # 229
# The City is Alice Springs
# -----------------------------------
# Processing: City # 230
# The City is Saskylakh
# -----------------------------------
# Processing: City # 231
# The City is Manzhouli
# -----------------------------------
# Processing: City # 232
# The City is Deutschlandsberg
# -----------------------------------
# Processing: City # 233
# The City is Skjervøy
# -----------------------------------
# Processing: City # 234
# The City is Dzhebariki-Khaya
# -----------------------------------
# Processing: City # 235
# The City is Husavik
# -----------------------------------
# Processing: City # 236
# The City is Newport
# -----------------------------------
# Processing: City # 237
# The City is Nome
# -----------------------------------
# Processing: City # 238
# The City is Río Gallegos
# -----------------------------------
# Processing: City # 239
# The City is Kristinestad
# -----------------------------------
# Processing: City # 240
# The City is Vila Velha
# -----------------------------------
# Processing: City # 241
# The City is Lufilufi
# -----------------------------------
# Processing: City # 242
# The City is Indramayu
# -----------------------------------
# Processing: City # 243
# The City is Batagay-Alyta
# -----------------------------------
# Processing: City # 244
# The City is Inhambane
# -----------------------------------
# Processing: City # 245
# The City is Ranong
# -----------------------------------
# Processing: City # 246
# The City is Chapais
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 247
# The City is Iregszemcse
# -----------------------------------
# Processing: City # 248
# The City is Bredasdorp
# -----------------------------------
# Processing: City # 249
# The City is Capitán Bado
# -----------------------------------
# Processing: City # 250
# The City is Puerto Escondido
# -----------------------------------
# Processing: City # 251
# The City is Dakar
# -----------------------------------
# Processing: City # 252
# The City is Ilulissat
# -----------------------------------
# Processing: City # 253
# The City is Nizwá
# -----------------------------------
# Processing: City # 254
# The City is Quatre Cocos
# -----------------------------------
# Processing: City # 255
# The City is La Orilla
# -----------------------------------
# Processing: City # 256
# The City is Chegdomyn
# -----------------------------------
# Processing: City # 257
# The City is Harsīn
# -----------------------------------
# Processing: City # 258
# The City is Laurinburg
# -----------------------------------
# Processing: City # 259
# The City is Khovd
# -----------------------------------
# Processing: City # 260
# The City is Aykhal
# -----------------------------------
# Processing: City # 261
# The City is Kotel'nich
# -----------------------------------
# Processing: City # 262
# The City is Dubbo
# -----------------------------------
# Processing: City # 263
# The City is Mukhen
# -----------------------------------
# Processing: City # 264
# The City is Adrar
# -----------------------------------
# Processing: City # 265
# The City is Huty
# -----------------------------------
# Processing: City # 266
# The City is Mocuba
# -----------------------------------
# Processing: City # 267
# The City is Chuncheng
# -----------------------------------
# Processing: City # 268
# The City is Gijang
# -----------------------------------
# Processing: City # 269
# The City is Cockburn Town
# -----------------------------------
# Processing: City # 270
# The City is Hervey Bay
# -----------------------------------
# Processing: City # 271
# The City is Taunggyi
# -----------------------------------
# Processing: City # 272
# The City is Santa Helena de Goiás
# -----------------------------------
# Processing: City # 273
# The City is Lagoa Formosa
# -----------------------------------
# Processing: City # 274
# The City is Salalah
# -----------------------------------
# Processing: City # 275
# The City is Okato
# -----------------------------------
# Processing: City # 276
# The City is Stralsund
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 277
# The City is Hobyo
# -----------------------------------
# Processing: City # 278
# The City is Paraíso
# -----------------------------------
# Processing: City # 279
# The City is Eyl
# -----------------------------------
# Processing: City # 280
# The City is Kitob
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 281
# The City is Tegul'det
# -----------------------------------
# Processing: City # 282
# The City is Bogorodskoye
# -----------------------------------
# Processing: City # 283
# The City is São Filipe
# -----------------------------------
# City Data is Missing
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 284
# The City is Katherine
# -----------------------------------
# Processing: City # 285
# The City is Ocampo
# -----------------------------------
# Processing: City # 286
# The City is Kaseda-shirakame
# -----------------------------------
# Processing: City # 287
# The City is Samfya
# -----------------------------------
# Processing: City # 288
# The City is Zhangye
# -----------------------------------
# Processing: City # 289
# The City is Ahipara
# -----------------------------------
# Processing: City # 290
# The City is Oktyabr'skiy
# -----------------------------------
# Processing: City # 291
# The City is Noyabrsk
# -----------------------------------
# Processing: City # 292
# The City is Asău
# -----------------------------------
# Processing: City # 293
# The City is Buala
# -----------------------------------
# Processing: City # 294
# The City is Sūsangerd
# -----------------------------------
# Processing: City # 295
# The City is Berlevåg
# -----------------------------------
# Processing: City # 296
# The City is Dunedin
# -----------------------------------
# Processing: City # 297
# The City is Codrington
# -----------------------------------
# Processing: City # 298
# The City is Huai'an
# -----------------------------------
# Processing: City # 299
# The City is São João da Barra
# -----------------------------------
# Processing: City # 300
# The City is Kiryat Gat
# -----------------------------------
# Processing: City # 301
# The City is Padang
# -----------------------------------
# Processing: City # 302
# The City is Kurgan
# -----------------------------------
# Processing: City # 303
# The City is Waddān
# -----------------------------------
# Processing: City # 304
# The City is Hualmay
# -----------------------------------
# Processing: City # 305
# The City is Malpe
# -----------------------------------
# Processing: City # 306
# The City is Chokurdakh
# -----------------------------------
# Processing: City # 307
# The City is Bonavista
# -----------------------------------
# Processing: City # 308
# The City is Kawalu
# -----------------------------------
# Processing: City # 309
# The City is Muli
# -----------------------------------
# Processing: City # 310
# The City is San Jerónimo
# -----------------------------------
# Processing: City # 311
# The City is Sakakah
# -----------------------------------
# Processing: City # 312
# The City is Orocué
# -----------------------------------
# Processing: City # 313
# The City is Imbituba
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 314
# The City is Luga
# -----------------------------------
# Processing: City # 315
# The City is Norman Wells
# -----------------------------------
# Processing: City # 316
# The City is Kumëny
# -----------------------------------
# Processing: City # 317
# The City is Jalu
# -----------------------------------
# Processing: City # 318
# The City is Hammerfest
# -----------------------------------
# Processing: City # 319
# The City is Porto-Novo
# -----------------------------------
# Processing: City # 320
# The City is Aberystwyth
# -----------------------------------
# Processing: City # 321
# The City is Provideniya
# -----------------------------------
# Processing: City # 322
# The City is Ormara
# -----------------------------------
# Processing: City # 323
# The City is Alofi
# -----------------------------------
# Processing: City # 324
# The City is Rio Grande
# -----------------------------------
# Processing: City # 325
# The City is Luwingu
# -----------------------------------
# Processing: City # 326
# The City is Henties Bay
# -----------------------------------
# Processing: City # 327
# The City is Cherskiy
# -----------------------------------
# Processing: City # 328
# The City is Sawākin
# -----------------------------------
# Processing: City # 329
# The City is Lamar
# -----------------------------------
# Processing: City # 330
# The City is Meulaboh
# -----------------------------------
# Processing: City # 331
# The City is Sioux Lookout
# -----------------------------------
# Processing: City # 332
# The City is Helsinge
# -----------------------------------
# Processing: City # 333
# The City is Goderich
# -----------------------------------
# Processing: City # 334
# The City is Aborlan
# -----------------------------------
# Processing: City # 335
# The City is Havelock
# -----------------------------------
# Processing: City # 336
# The City is Huatulco
# -----------------------------------
# Processing: City # 337
# The City is Arrondissement de Lisieux
# -----------------------------------
# Processing: City # 338
# The City is Conneaut
# -----------------------------------
# Processing: City # 339
# The City is Marsá Maţrūḩ
# -----------------------------------
# Processing: City # 340
# The City is Turangi
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 341
# The City is College
# -----------------------------------
# Processing: City # 342
# The City is Lalín
# -----------------------------------
# Processing: City # 343
# The City is Waingapu
# -----------------------------------
# Processing: City # 344
# The City is Turukhansk
# -----------------------------------
# Processing: City # 345
# The City is Yulara
# -----------------------------------
# Processing: City # 346
# The City is Petropavlovsk-Kamchatskiy
# -----------------------------------
# Processing: City # 347
# The City is Port Blair
# -----------------------------------
# Processing: City # 348
# The City is Myaundzha
# -----------------------------------
# Processing: City # 349
# The City is Talaya
# -----------------------------------
# Processing: City # 350
# The City is Qui Nhon
# -----------------------------------
# Processing: City # 351
# The City is Requena
# -----------------------------------
# Processing: City # 352
# The City is Kholodnyy
# -----------------------------------
# Processing: City # 353
# The City is Ayamé
# -----------------------------------
# Processing: City # 354
# The City is Saint George
# -----------------------------------
# Processing: City # 355
# The City is Port-Gentil
# -----------------------------------
# Processing: City # 356
# The City is Terney
# -----------------------------------
# Processing: City # 357
# The City is Ivybridge
# -----------------------------------
# Processing: City # 358
# The City is Selikhino
# -----------------------------------
# Processing: City # 359
# The City is Cayenne
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 360
# The City is Saint-Pierre
# -----------------------------------
# Processing: City # 361
# The City is San Quintín
# -----------------------------------
# Processing: City # 362
# The City is Maragogi
# -----------------------------------
# Processing: City # 363
# The City is Yuanping
# -----------------------------------
# Processing: City # 364
# The City is High Level
# -----------------------------------
# Processing: City # 365
# The City is Vernon
# -----------------------------------
# Processing: City # 366
# The City is Escanaba
# -----------------------------------
# Processing: City # 367
# The City is Itainópolis
# -----------------------------------
# Processing: City # 368
# The City is Olinda
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 369
# The City is Beitbridge
# -----------------------------------
# Processing: City # 370
# The City is Oranjestad
# -----------------------------------
# Processing: City # 371
# The City is Dargaville
# -----------------------------------
# Processing: City # 372
# The City is Ust-Nera
# -----------------------------------
# Processing: City # 373
# The City is Paamiut
# -----------------------------------
# Processing: City # 374
# The City is Ubari
# -----------------------------------
# Processing: City # 375
# The City is Utevka
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 376
# The City is Saint-Joseph
# -----------------------------------
# Processing: City # 377
# The City is Kikinda
# -----------------------------------
# Processing: City # 378
# The City is San Juan Evangelista
# -----------------------------------
# Processing: City # 379
# The City is Baykit
# -----------------------------------
# Processing: City # 380
# The City is Ucluelet
# -----------------------------------
# Processing: City # 381
# The City is Bonthe
# -----------------------------------
# Processing: City # 382
# The City is Wanning
# -----------------------------------
# Processing: City # 383
# The City is Gravdal
# -----------------------------------
# Processing: City # 384
# The City is Ponta Delgada
# -----------------------------------
# Processing: City # 385
# The City is Kologriv
# -----------------------------------
# Processing: City # 386
# The City is Koumac
# -----------------------------------
# Processing: City # 387
# The City is Sennar
# -----------------------------------
# City Data is Missing
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 388
# The City is Port Lincoln
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 389
# The City is Lilongwe
# -----------------------------------
# Processing: City # 390
# The City is Cândido de Abreu
# -----------------------------------
# Processing: City # 391
# The City is Tasiilaq
# -----------------------------------
# Processing: City # 392
# The City is Savonlinna
# -----------------------------------
# Processing: City # 393
# The City is Margate
# -----------------------------------
# Processing: City # 394
# The City is Virginia Beach
# -----------------------------------
# Processing: City # 395
# The City is Marsh Harbour
# -----------------------------------
# Processing: City # 396
# The City is Hanyang
# -----------------------------------
# Processing: City # 397
# The City is Zaysan
# -----------------------------------
# Processing: City # 398
# The City is Mayo
# -----------------------------------
# Processing: City # 399
# The City is Muravlenko
# -----------------------------------
# Processing: City # 400
# The City is Biel/Bienne
# -----------------------------------
# Processing: City # 401
# The City is Neuquén
# -----------------------------------
# Processing: City # 402
# The City is Ekhabi
# -----------------------------------
# Processing: City # 403
# The City is Bushehr
# -----------------------------------
# Processing: City # 404
# The City is Praia da Vitória
# -----------------------------------
# Processing: City # 405
# The City is Bilma
# -----------------------------------
# Processing: City # 406
# The City is Umm Kaddadah
# -----------------------------------
# City Data is Missing
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 407
# The City is Grand Forks
# -----------------------------------
# Processing: City # 408
# The City is Punto Fijo
# -----------------------------------
# Processing: City # 409
# The City is Ndélé
# -----------------------------------
# Processing: City # 410
# The City is Ürümqi
# -----------------------------------
# Processing: City # 411
# The City is Embonas
# -----------------------------------
# Processing: City # 412
# The City is Grand Gaube
# -----------------------------------
# Processing: City # 413
# The City is Lata
# -----------------------------------
# Processing: City # 414
# The City is Chissamba
# -----------------------------------
# Processing: City # 415
# The City is Sungai Penuh
# -----------------------------------
# Processing: City # 416
# The City is Sines Municipality
# -----------------------------------
# Processing: City # 417
# The City is Diffa
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 418
# The City is Nísia Floresta
# -----------------------------------
# Processing: City # 419
# The City is Niesky
# -----------------------------------
# Processing: City # 420
# The City is Wairoa
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 421
# The City is Karratha
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 422
# The City is Blackwater
# -----------------------------------
# Processing: City # 423
# The City is Bol
# -----------------------------------
# Processing: City # 424
# The City is Sittwe
# -----------------------------------
# Processing: City # 425
# The City is Tocopilla
# -----------------------------------
# Processing: City # 426
# The City is Nanortalik
# -----------------------------------
# Processing: City # 427
# The City is Fereydūnkenār
# -----------------------------------
# Processing: City # 428
# The City is Soyo
# -----------------------------------
# Processing: City # 429
# The City is Cuiluan
# -----------------------------------
# Processing: City # 430
# The City is San Cristobal
# -----------------------------------
# Processing: City # 431
# The City is Kaeo
# -----------------------------------
# Processing: City # 432
# The City is Yerbogachën
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 433
# The City is Tiksi
# -----------------------------------
# Processing: City # 434
# The City is Fairbanks
# -----------------------------------
# Processing: City # 435
# The City is Yar-Sale
# -----------------------------------
# Processing: City # 436
# The City is Los Llanos de Aridane
# -----------------------------------
# Processing: City # 437
# The City is Antalaha
# -----------------------------------
# Processing: City # 438
# The City is Beringovskiy
# -----------------------------------
# Processing: City # 439
# The City is Santa Fe
# -----------------------------------
# Processing: City # 440
# The City is Belmonte
# -----------------------------------
# Processing: City # 441
# The City is Ialibu
# -----------------------------------
# Processing: City # 442
# The City is Rosario
# -----------------------------------
# Processing: City # 443
# The City is Naze
# -----------------------------------
# Processing: City # 444
# The City is Insar
# -----------------------------------
# Processing: City # 445
# The City is Dudinka
# -----------------------------------
# Processing: City # 446
# The City is San Luis
# -----------------------------------
# Processing: City # 447
# The City is Oranjemund
# -----------------------------------
# Processing: City # 448
# The City is Manavālakurichi
# -----------------------------------
# Processing: City # 449
# The City is Makakilo City
# -----------------------------------
# Processing: City # 450
# The City is Orlik
# -----------------------------------
# Processing: City # 451
# The City is Walvis Bay
# -----------------------------------
# Processing: City # 452
# The City is Bara
# -----------------------------------
# Processing: City # 453
# The City is Semey
# -----------------------------------
# Processing: City # 454
# The City is Marabu
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 455
# The City is Mahendranagar
# -----------------------------------
# Processing: City # 456
# The City is Warmbad
# -----------------------------------
# Processing: City # 457
# The City is Careiro da Várzea
# -----------------------------------
# Processing: City # 458
# The City is Dongning
# -----------------------------------
# Processing: City # 459
# The City is Taoudenni
# -----------------------------------
# Processing: City # 460
# The City is Concarneau
# -----------------------------------
# Processing: City # 461
# The City is Grand-Santi
# -----------------------------------
# Processing: City # 462
# The City is Basco
# -----------------------------------
# Processing: City # 463
# The City is Sinop Province
# -----------------------------------
# Processing: City # 464
# The City is Dabakala
# -----------------------------------
# Processing: City # 465
# The City is Lumding
# -----------------------------------
# Processing: City # 466
# The City is Dingle
# -----------------------------------
# Processing: City # 467
# The City is Sawang Daen Din
# -----------------------------------
# Processing: City # 468
# The City is Araouane
# -----------------------------------
# Processing: City # 469
# The City is Ostrovnoy
# -----------------------------------
# Processing: City # 470
# The City is Namtsy
# -----------------------------------
# Processing: City # 471
# The City is Vanavara
# -----------------------------------
# Processing: City # 472
# The City is Port Hardy
# -----------------------------------
# Processing: City # 473
# The City is Sovetskiy
# -----------------------------------
# Processing: City # 474
# The City is Mazyr
# -----------------------------------
# Processing: City # 475
# The City is Tambopata
# -----------------------------------
# Processing: City # 476
# The City is Makaha
# -----------------------------------
# Processing: City # 477
# The City is Emerald
# -----------------------------------
# Processing: City # 478
# The City is Złotów
# -----------------------------------
# Processing: City # 479
# The City is Yakeshi
# -----------------------------------
# Processing: City # 480
# The City is Luebo
# -----------------------------------
# Processing: City # 481
# The City is Jesup
# -----------------------------------
# Processing: City # 482
# The City is Ouadda
# -----------------------------------
# Processing: City # 483
# The City is Campbell River
# -----------------------------------
# Processing: City # 484
# The City is Touros
# -----------------------------------
# Processing: City # 485
# The City is Chernogorsk
# -----------------------------------
# Processing: City # 486
# The City is Kargopol'
# -----------------------------------
# Processing: City # 487
# The City is Rovnoye
# -----------------------------------
# Processing: City # 488
# The City is Springdale
# -----------------------------------
# Processing: City # 489
# The City is São Félix do Xingu
# -----------------------------------
# Processing: City # 490
# The City is Pangkalanbuun
# -----------------------------------
# Processing: City # 491
# The City is Ngama
# -----------------------------------
# Processing: City # 492
# The City is Churhat
# -----------------------------------
# Processing: City # 493
# The City is Boddam
# -----------------------------------
# Processing: City # 494
# The City is Grindavik
# -----------------------------------
# Processing: City # 495
# The City is Nuevo Ideal
# -----------------------------------
# Processing: City # 496
# The City is Myitkyina
# -----------------------------------
# Processing: City # 497
# The City is Methóni
# -----------------------------------
# Processing: City # 498
# The City is Kumta
# -----------------------------------
# Processing: City # 499
# The City is Dunmore Town
# -----------------------------------
# Processing: City # 500
# The City is Hatillo
# -----------------------------------
# City Data is Missing
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 501
# The City is Puerto Carreño
# -----------------------------------
# Processing: City # 502
# The City is Sidi Ali
# -----------------------------------
# Processing: City # 503
# The City is Jaswantnagar
# -----------------------------------
# Processing: City # 504
# The City is Labuan
# -----------------------------------
# Processing: City # 505
# The City is Voi
# -----------------------------------
# Processing: City # 506
# The City is Bontang
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 507
# The City is Grootfontein
# -----------------------------------
# Processing: City # 508
# The City is Kyaikkami
# -----------------------------------
# Processing: City # 509
# The City is Isla Mujeres
# -----------------------------------
# Processing: City # 510
# The City is Havre-St-Pierre
# -----------------------------------
# Processing: City # 511
# The City is Rosarito
# -----------------------------------
# Processing: City # 512
# The City is Kloulklubed
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 513
# The City is Mercedes
# -----------------------------------
# Processing: City # 514
# The City is Doha
# -----------------------------------
# Processing: City # 515
# The City is Williston
# -----------------------------------
# Processing: City # 516
# The City is Borgarnes
# -----------------------------------
# Processing: City # 517
# The City is Abengourou
# -----------------------------------
# Processing: City # 518
# The City is Cap-aux-Meules
# -----------------------------------
# Processing: City # 519
# The City is Biak
# -----------------------------------
# Processing: City # 520
# The City is Donskoye
# -----------------------------------
# Processing: City # 521
# The City is Bariloche
# -----------------------------------
# Processing: City # 522
# The City is Weligama
# -----------------------------------
# Processing: City # 523
# The City is Saint Anthony
# -----------------------------------
# Processing: City # 524
# The City is ‘Āhuimanu
# -----------------------------------
# Processing: City # 525
# The City is Salta
# -----------------------------------
# Processing: City # 526
# The City is Bumbuna
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 527
# The City is Xai-Xai
# -----------------------------------
# Processing: City # 528
# The City is Tura
# -----------------------------------
# Processing: City # 529
# The City is Ratnagiri
# -----------------------------------
# Processing: City # 530
# The City is Narganá
# -----------------------------------
# Processing: City # 531
# The City is Santa Maria
# -----------------------------------
# Processing: City # 532
# The City is Raudeberg
# -----------------------------------
# Processing: City # 533
# The City is Aswān
# -----------------------------------
# Processing: City # 534
# The City is Belen
# -----------------------------------
# Processing: City # 535
# The City is Villarrica
# -----------------------------------
# Processing: City # 536
# The City is Abu Dhabi
# -----------------------------------
# Processing: City # 537
# The City is Vathy
# -----------------------------------
# Processing: City # 538
# The City is Clyde River
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 539
# The City is Mahanoro
# -----------------------------------
# Processing: City # 540
# The City is Abrau-Dyurso
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 541
# The City is Acapulco de Juárez
# -----------------------------------
# Processing: City # 542
# The City is Hirara
# -----------------------------------
# Processing: City # 543
# The City is Castlegar
# -----------------------------------
# Processing: City # 544
# The City is Gemeente Woerden
# -----------------------------------
# Processing: City # 545
# The City is Xining
# -----------------------------------
# City Data is Missing
# -----------------------------------
# Processing: City # 546
# The City is Haimen
# -----------------------------------
# Processing: City # 547
# The City is Itaituba
# -----------------------------------
# Processing: City # 548
# The City is Necochea
# -----------------------------------
# Processing: City # 549
# The City is Kamenka
# -----------------------------------
# Processing: City # 550
# The City is Najrān
# -----------------------------------
# Processing: City # 551
# The City is Great Falls
# -----------------------------------
# Processing: City # 552
# The City is Nuuk
# -----------------------------------
# Processing: City # 553
# The City is Moerai
# -----------------------------------
# Processing: City # 554
# The City is Sayaxché
# -----------------------------------
# Processing: City # 555
# The City is Opuwo
# -----------------------------------
# Processing: City # 556
# The City is Ballina
# -----------------------------------
# Processing: City # 557
# The City is Huarmey
# -----------------------------------
# Processing: City # 558
# The City is Changtu
# -----------------------------------
# Processing: City # 559
# The City is Camapuã
# -----------------------------------
# Processing: City # 560
# The City is Dwārka
# -----------------------------------
# Processing: City # 561
# The City is Yangi Marg`ilon
# -----------------------------------
# Processing: City # 562
# The City is Ushirombo
# -----------------------------------
# Processing: City # 563
# The City is Xiantao
# -----------------------------------
# Processing: City # 564
# The City is Mbanza-Ngungu
# -----------------------------------
# Processing: City # 565
# The City is Itaberá
# -----------------------------------
# Processing: City # 566
# The City is Egvekinot
# -----------------------------------
# Processing: City # 567
# The City is Magadan
# -----------------------------------
# Processing: City # 568
# The City is Mahon
# -----------------------------------
# Processing: City # 569
# The City is Mackay
# -----------------------------------
# Processing: City # 570
# The City is Preobrazheniye
# -----------------------------------
# Processing: City # 571
# The City is Sabang
# -----------------------------------
# Processing: City # 572
# The City is Wellington
# -----------------------------------
# Processing: City # 573
# The City is Launceston
# Data Retrieval is now Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citiesdf.count()
# Out:
# City                   617
# Country                617
# Date                   617
# Latitude               617
# Longitude              617
# Max Temperature (F)    617
# Humidity (%)           617
# Cloudiness (%)         617
# Wind Speed (mph)       617
# dtype: int64

# %%
citiesdf.to_csv("WeatherPy_City.csv", index=False)
citiesdf = pd.read_csv("WeatherPy_City.csv")

# %%
#Drop blank cells
citiesdf.dropna(inplace=True)
citiesdf.head()
# Out:
#              City Country          Date  Latitude  Longitude  \
# 0         Rikitea      PF  1.595127e+09    -23.12    -134.97
# 1  Port Macquarie      AU  1.595126e+09    -31.43     152.92
# 2           Vardø      NO  1.595127e+09     70.37      31.11
# 3           Bluff      NZ  1.595127e+09    -46.60     168.33
# 4        Tazovsky      RU  1.595127e+09     67.47      78.70
#
#    Max Temperature (F)  Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0                70.23          82.0            98.0             14.56
# 1                69.01          55.0             0.0              1.01
# 2                50.95          87.0            95.0              5.30
# 3                46.98          62.0             1.0              4.43
# 4                53.33          64.0            96.0             11.10

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build the scatter plots 
plt.scatter(citiesdf['Latitude'], citiesdf['Max Temperature (F)'], linewidth=1, marker="o", 
            alpha=0.5, facecolor="blue", edgecolor="black", label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature {time.strftime('%m/%d/%y')}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperture (F)")
plt.grid(True)

plt.savefig("Latitude_Temperature.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
citiesdf=citiesdf[(citiesdf['Humidity (%)']<=100)]

# %%
# Build the scatter plots 
plt.scatter(citiesdf['Latitude'], citiesdf['Humidity (%)'], linewidth=1, marker="o", 
            alpha=0.5, facecolor="blue", edgecolor="black", label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity {time.strftime('%m/%d/%y')}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

plt.savefig("Latitude_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots 
plt.scatter(citiesdf['Latitude'], citiesdf['Cloudiness (%)'], linewidth=1, marker="o", 
            alpha=0.5, facecolor="blue", edgecolor="black", label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness {time.strftime('%m/%d/%y')}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

plt.savefig("Latitude_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots 
plt.scatter(citiesdf['Latitude'], citiesdf['Wind Speed (mph)'], linewidth=1, marker="o", 
            alpha=0.5, facecolor="blue", edgecolor="black", label="City")

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed {time.strftime('%m/%d/%y')}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)

plt.savefig("Latitude_WindSpeed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
